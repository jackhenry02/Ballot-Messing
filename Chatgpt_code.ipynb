# %%
import requests
from bs4 import BeautifulSoup

# Function to fetch HTML content from a URL
def fetch_html(url):
    response = requests.get(url)
    return response.content

# Function to parse student preferences from HTML table
def parse_student_preferences(html_content):
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    # Extract student preferences from HTML table
    # (You'll need to inspect the HTML structure of the webpage to identify the relevant elements)
    return student_preferences

# Function to parse room popularity from HTML table
def parse_room_popularity(html_content):
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    # Extract room popularity from HTML table
    # (You'll need to inspect the HTML structure of the webpage to identify the relevant elements)
    return room_popularity

# Function to implement Gale-Shapley algorithm
def gale_shapley(preferences_students, preferences_rooms):
    # Implement Gale-Shapley algorithm here
    # Students propose to rooms based on their preferences
    # Rooms tentatively accept or reject proposals until each room is filled to capacity
    return room_assignments

# Function to implement top-down propagation
def top_down_propagation(room_popularity, room_assignments):
    # Implement top-down propagation here
    # Highly popular rooms propose to students first
    # Students accept or reject proposals based on their preferences
    return final_room_assignments

# URL of the webpage containing student preferences table
url_student_preferences = 'https://example.com/student_preferences'

# URL of the webpage containing room popularity table
url_room_popularity = 'https://example.com/room_popularity'

# Fetch HTML content from both URLs
html_content_student_preferences = fetch_html(url_student_preferences)
html_content_room_popularity = fetch_html(url_room_popularity)

# Parse student preferences and room popularity from HTML tables
student_preferences = parse_student_preferences(html_content_student_preferences)
room_popularity = parse_room_popularity(html_content_room_popularity)

# Implement Gale-Shapley algorithm to allocate rooms based on student preferences
room_assignments = gale_shapley(student_preferences, room_popularity)

# Implement top-down propagation to further refine room allocations based on popularity
final_room_assignments = top_down_propagation(room_popularity, room_assignments)

# Print final room allocations
print("Final Room Allocations:")
for student, room in final_room_assignments.items():
    print(f"{student} is assigned to {room}")
